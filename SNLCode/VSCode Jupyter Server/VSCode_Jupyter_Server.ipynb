# %%
# Install jupyterlab and ngrok
# !pip install jupyterlab==2.2.9 pyngrok -q

# Run jupyterlab in background
# !nohup jupyter lab --ip=0.0.0.0 &

# Make jupyterlab accessible via ngrok
from pyngrok import ngrok
print(ngrok.connect(8888))
# Out:
#      |████████████████████████████████| 7.9MB 9.1MB/s
#      |████████████████████████████████| 747kB 36.1MB/s
#      |████████████████████████████████| 61kB 7.1MB/s
#   Building wheel for pyngrok (setup.py) ... done
# ERROR: nbclient 0.5.3 has requirement jupyter-client>=6.1.5, but you'll have jupyter-client 5.3.5 which is incompatible.
# nohup: appending output to 'nohup.out'
# NgrokTunnel: "http://d1ef7eafbea2.ngrok.io" -> "http://localhost:8888"

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
while(1):
  print("")
# Out:
# Streaming output truncated to the last 5000 lines.
