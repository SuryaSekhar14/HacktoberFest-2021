# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
import random

# %%
X,Y=make_blobs(n_samples=500,centers=5,random_state=3)

# %%
print(X.shape,Y.shape)
# Out:
# (500, 2) (500,)

# %%
plt.figure(0)
plt.grid(True)
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
k=5

color=['green','red','blue','yellow','orange']
clusters={}

for i in range(k):
    center= 10*(2*np.random((X.shape[1],))-1) #generating point between -10 to 10
    points=[]
    
    cluster={
             'center': center,
             'points':points
             'color':color[i]
        
              }
    clusters[i]=cluster
# Out:
#   File "/var/folders/vd/lb0gkn7j2t34s4ljbgdb7g5r0000gn/T/ipykernel_1512/2533677782.py", line 13
#     'color':color[i]
#     ^
# SyntaxError: invalid syntax

# %%
clusters
# Out:
# {0: {'center': array([-0.50034996,  2.75316253]),
#   'points': [],
#   'color': 'green'},
#  1: {'center': array([-8.1430244 , -3.14449931]),
#   'points': [],
#   'color': 'red'},
#  2: {'center': array([7.73617083, 7.93307561]), 'points': [], 'color': 'blue'},
#  3: {'center': array([-4.17628235,  0.16605794]),
#   'points': [],
#   'color': 'yellow'},
#  4: {'center': array([9.02413655, 8.40113046]),
#   'points': [],
#   'color': 'orange'}}

# %%
def distance(v1,v2):
    return np.sqrt(np.sum((v1-v2)**2))

# %%
v1=np.array([1,2])
v2=np.array([3,5])
distance(v1,v2)
# Out:
# 3.605551275463989

# %%
#E step - Assign evry point to one of the clusters 

def assignPointsToClusters(clusters):
    
    for i in range(X.shape[0]):
        dist=[]
        curr_point=X[i]

        for kx in range(k):
            d=distance(curr_point,clusters[kx]['center'])
            dist.append(d)

            curr_cluster=np.argmin(dist)

            clusters[curr_cluster]['points'].append(curr_point)
        
def UpdateClusters(clusters): #M-Step update every cluster center according to mean of points
    
    for kx in range(k):
        #pts=np.array(clusters[kx]['points'])
        print(clusters[kx]['points'])
        
        if pts.shape[0]>0:  #to check if the cluster is not empty
            new_center = pts.mean(axis=0)
            clusters[kx]['center']=new_center
            cluster[kx]['points']=[]
        


def plotClusters(clusters):
    
    for kx in range(k):
        pts=np.array(clusters[kx]['points'])
        #print(pts.shape)
        
        try:
            plt.scatter(pts[:,0],pts[:,1],color=clusters[kx]['color'])
        except:
            pass
        
        #plotting clusters center
        center=clusters[kx]['center']
        plt.scatter(center[0],center[1],color='black',marker='*')

# %%
assignPointsToClusters(clusters)
plotClusters(clusters)

# %%
assignPointsToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)

# %%
assignPointsToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)

# %%
assignPointsToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)

# %%
assignPointsToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)

# %%
assignPointsToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)

# %%
assignPointsToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)

# %%
assignPointsToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)

# %% [markdown]
# ### K-Means++

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
X,Y=make_blobs(n_samples=500,centers=5,random_state=3,n_features=2)

# %%
from sklearn.cluster import KMeans

# %%
kmeans=KMeans(n_clusters=5)

# %%
kmeans.fit(X,Y)
# Out:
# KMeans(n_clusters=5)

# %%
centers=kmeans.cluster_centers_

# %%
plt.scatter(X[:,0],X[:,1])
plt.scatter(centers[:,0],centers[:,1])
plt.show()

# %%
pred=kmeans.labels_

# %%
print(pred)
# Out:
# [4 3 0 4 4 0 2 4 3 4 3 0 3 4 0 4 3 4 4 3 1 1 4 0 4 1 2 2 0 2 4 2 1 1 4 1 3
#  3 4 1 1 1 2 2 0 3 3 2 2 2 3 4 2 4 4 1 4 4 3 0 3 0 0 4 2 3 0 0 1 0 1 4 1 4
#  1 0 4 2 1 1 0 1 0 2 3 2 0 3 2 0 2 1 4 1 1 3 4 0 0 1 3 1 0 0 3 3 3 0 0 4 3
#  2 4 3 0 1 3 2 1 0 3 0 2 4 1 2 2 2 4 4 0 0 4 3 3 2 0 2 0 4 4 1 0 3 2 4 3 3
#  4 0 4 4 0 0 3 1 1 2 0 4 1 3 2 1 3 1 3 1 1 1 2 4 1 3 1 2 4 0 3 2 3 4 3 1 2
#  2 1 4 0 3 1 0 2 4 2 1 0 2 4 4 4 1 1 3 4 2 2 4 3 4 4 4 1 3 0 3 4 4 3 2 0 2
#  2 1 4 0 4 0 2 1 0 0 4 1 4 1 0 3 0 1 1 3 4 4 0 0 1 3 1 4 2 3 2 4 2 2 2 2 3
#  1 3 4 1 3 2 0 3 3 3 2 4 4 0 1 1 3 0 0 4 0 2 0 3 3 2 2 1 2 2 3 1 4 0 1 0 2
#  0 0 3 4 1 3 1 1 4 2 1 0 1 2 4 4 0 3 1 2 3 1 0 2 3 2 4 1 2 0 0 1 1 1 4 2 1
#  4 3 0 0 2 3 3 0 0 2 1 1 1 4 2 3 2 4 1 3 3 0 1 1 2 1 2 0 0 0 2 1 4 1 0 2 2
#  3 4 3 2 4 2 0 3 1 3 0 4 4 3 3 1 3 1 2 0 3 2 4 4 3 0 1 2 4 4 4 2 3 1 3 3 3
#  2 1 0 3 0 0 2 0 4 0 4 3 1 1 4 3 2 4 1 0 3 2 0 2 2 3 2 0 2 3 2 0 2 4 1 1 2
#  1 3 1 1 2 4 4 0 2 1 0 2 0 3 0 3 4 1 0 4 0 4 4 1 4 1 2 3 3 0 4 4 2 2 3 2 2
#  3 2 3 3 3 2 1 2 0 3 0 0 2 0 2 1 1 2 3]

# %%
plt.scatter(X[:,0],X[:,1],c=pred)
plt.scatter(centers[:,0],centers[:,1])
plt.show()

# %%
#ACTUAL PLOTTING ACCORDING TO LABELS
plt.scatter(X[:,0],X[:,1],c=Y)
plt.scatter(centers[:,0],centers[:,1])
plt.show()
